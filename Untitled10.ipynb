# %% [markdown]
# <a href="https://colab.research.google.com/github/TANISHAJAMUAR/skill-craft-technology/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import plotly.express as px

# %%
fig_hist = px.histogram(df, x='Age', nbins=20, title='Population Age Distribution')
fig_hist.update_layout(
    xaxis_title='Age (years)',
    yaxis_title='Frequency',
    title_x=0.5,
    font=dict(size=14)
)
fig_hist.update_xaxes(tick0=0, dtick=10)
fig_hist.update_traces(marker_line_width=0)
fig_hist.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd
import numpy as np

# Create a sample DataFrame for demonstration
np.random.seed(42)
data = {
    'Age': np.random.randint(18, 65, size=100),
    'Gender': np.random.choice(['Male', 'Female'], size=100),
    'City': np.random.choice(['New York', 'Los Angeles', 'Chicago'], size=100)
}
df = pd.DataFrame(data)

print("Sample DataFrame 'df' created:")
display(df.head())
# Out:
# Sample DataFrame 'df' created:
#    Age  Gender         City
# 0   56  Female     New York
# 1   46  Female      Chicago
# 2   32    Male  Los Angeles
# 3   60    Male     New York
# 4   25    Male     New York
